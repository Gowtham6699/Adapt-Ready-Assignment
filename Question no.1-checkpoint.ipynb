# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\maniv\\Downloads\\complaints.csv\\complaints.csv")
# Out:
# C:\Users\maniv\AppData\Local\Temp\ipykernel_30716\2343698652.py:1: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("C:\\Users\\maniv\\Downloads\\complaints.csv\\complaints.csv")

# %%
df
# Out:
#         Date received                                            Product  \
# 0          2024-01-23  Credit reporting or other personal consumer re...
# 1          2024-01-24  Credit reporting or other personal consumer re...
# 2          2024-01-24  Credit reporting or other personal consumer re...
# 3          2024-01-23  Credit reporting or other personal consumer re...
# 4          2024-01-23  Credit reporting or other personal consumer re...
# ...               ...                                                ...
# 5134962    2023-08-02  Credit reporting, credit repair services, or o...
# 5134963    2023-08-02          Payday loan, title loan, or personal loan
# 5134964    2023-08-02                                           Mortgage
# 5134965    2023-08-02  Credit reporting, credit repair services, or o...
# 5134966    2023-08-04          Payday loan, title loan, or personal loan
#
#               Sub-product                                              Issue  \
# 0        Credit reporting               Incorrect information on your report
# 1        Credit reporting               Incorrect information on your report
# 2        Credit reporting                        Improper use of your report
# 3        Credit reporting                        Improper use of your report
# 4        Credit reporting                        Improper use of your report
# ...                   ...                                                ...
# 5134962  Credit reporting               Incorrect information on your report
# 5134963  Installment loan  Problem with additional add-on products or ser...
# 5134964      FHA mortgage                         Struggling to pay mortgage
# 5134965  Credit reporting                        Improper use of your report
# 5134966       Payday loan         Charged fees or interest you didn't expect
#
#                                                  Sub-issue  \
# 0                      Information belongs to someone else
# 1                      Information belongs to someone else
# 2        Credit inquiries on your report that you don't...
# 3            Reporting company used your report improperly
# 4            Reporting company used your report improperly
# ...                                                    ...
# 5134962                Information belongs to someone else
# 5134963                                                NaN
# 5134964                                                NaN
# 5134965      Reporting company used your report improperly
# 5134966                                                NaN
#
#                               Consumer complaint narrative  \
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3        In accordance with the Fair Credit Reporting a...
# 4        I have observed several deviations from mandat...
# ...                                                    ...
# 5134962                                                NaN
# 5134963                                                NaN
# 5134964                                                NaN
# 5134965                                                NaN
# 5134966                                                NaN
#
#                                    Company public response  \
# 0        Company has responded to the consumer and the ...
# 1        Company has responded to the consumer and the ...
# 2        Company has responded to the consumer and the ...
# 3        Company has responded to the consumer and the ...
# 4        Company has responded to the consumer and the ...
# ...                                                    ...
# 5134962                                                NaN
# 5134963                                                NaN
# 5134964  Company believes it acted appropriately as aut...
# 5134965                                                NaN
# 5134966                                                NaN
#
#                                         Company State ZIP code Tags  \
# 0        TRANSUNION INTERMEDIATE HOLDINGS, INC.    ME    04005  NaN
# 1        TRANSUNION INTERMEDIATE HOLDINGS, INC.    FL    33311  NaN
# 2        TRANSUNION INTERMEDIATE HOLDINGS, INC.    PA    175XX  NaN
# 3        TRANSUNION INTERMEDIATE HOLDINGS, INC.    TX    79907  NaN
# 4        TRANSUNION INTERMEDIATE HOLDINGS, INC.    NY    10075  NaN
# ...                                         ...   ...      ...  ...
# 5134962                           EQUIFAX, INC.    TX    76036  NaN
# 5134963                        NBT BANCORP INC.    NJ    08046  NaN
# 5134964                           Chesmar Homes    TX    77316  NaN
# 5134965                           EQUIFAX, INC.    GA    30013  NaN
# 5134966            Flandreau Santee Sioux Tribe    TX    75057  NaN
#
#         Consumer consent provided? Submitted via Date sent to company  \
# 0             Consent not provided           Web           2024-01-23
# 1                            Other           Web           2024-01-24
# 2                            Other           Web           2024-01-24
# 3                 Consent provided           Web           2024-01-23
# 4                 Consent provided           Web           2024-01-23
# ...                            ...           ...                  ...
# 5134962                      Other           Web           2023-08-02
# 5134963                        NaN         Phone           2023-08-02
# 5134964                      Other           Web           2023-08-17
# 5134965       Consent not provided           Web           2023-08-02
# 5134966       Consent not provided           Web           2023-08-18
#
#             Company response to consumer Timely response? Consumer disputed?  \
# 0        Closed with non-monetary relief              Yes                NaN
# 1        Closed with non-monetary relief              Yes                NaN
# 2        Closed with non-monetary relief              Yes                NaN
# 3        Closed with non-monetary relief              Yes                NaN
# 4        Closed with non-monetary relief              Yes                NaN
# ...                                  ...              ...                ...
# 5134962  Closed with non-monetary relief              Yes                NaN
# 5134963          Closed with explanation              Yes                NaN
# 5134964          Closed with explanation              Yes                NaN
# 5134965          Closed with explanation              Yes                NaN
# 5134966          Closed with explanation              Yes                NaN
#
#          Complaint ID
# 0             8206605
# 1             8211390
# 2             8211362
# 3             8210433
# 4             8209430
# ...               ...
# 5134962       7337991
# 5134963       7343156
# 5134964       7340709
# 5134965       7341166
# 5134966       7350142
#
# [5134967 rows x 18 columns]

# %%
df.head()
# Out:
#   Date received                                            Product  \
# 0    2024-01-23  Credit reporting or other personal consumer re...
# 1    2024-01-24  Credit reporting or other personal consumer re...
# 2    2024-01-24  Credit reporting or other personal consumer re...
# 3    2024-01-23  Credit reporting or other personal consumer re...
# 4    2024-01-23  Credit reporting or other personal consumer re...
#
#         Sub-product                                 Issue  \
# 0  Credit reporting  Incorrect information on your report
# 1  Credit reporting  Incorrect information on your report
# 2  Credit reporting           Improper use of your report
# 3  Credit reporting           Improper use of your report
# 4  Credit reporting           Improper use of your report
#
#                                            Sub-issue  \
# 0                Information belongs to someone else
# 1                Information belongs to someone else
# 2  Credit inquiries on your report that you don't...
# 3      Reporting company used your report improperly
# 4      Reporting company used your report improperly
#
#                         Consumer complaint narrative  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  In accordance with the Fair Credit Reporting a...
# 4  I have observed several deviations from mandat...
#
#                              Company public response  \
# 0  Company has responded to the consumer and the ...
# 1  Company has responded to the consumer and the ...
# 2  Company has responded to the consumer and the ...
# 3  Company has responded to the consumer and the ...
# 4  Company has responded to the consumer and the ...
#
#                                   Company State ZIP code Tags  \
# 0  TRANSUNION INTERMEDIATE HOLDINGS, INC.    ME    04005  NaN
# 1  TRANSUNION INTERMEDIATE HOLDINGS, INC.    FL    33311  NaN
# 2  TRANSUNION INTERMEDIATE HOLDINGS, INC.    PA    175XX  NaN
# 3  TRANSUNION INTERMEDIATE HOLDINGS, INC.    TX    79907  NaN
# 4  TRANSUNION INTERMEDIATE HOLDINGS, INC.    NY    10075  NaN
#
#   Consumer consent provided? Submitted via Date sent to company  \
# 0       Consent not provided           Web           2024-01-23
# 1                      Other           Web           2024-01-24
# 2                      Other           Web           2024-01-24
# 3           Consent provided           Web           2024-01-23
# 4           Consent provided           Web           2024-01-23
#
#       Company response to consumer Timely response? Consumer disputed?  \
# 0  Closed with non-monetary relief              Yes                NaN
# 1  Closed with non-monetary relief              Yes                NaN
# 2  Closed with non-monetary relief              Yes                NaN
# 3  Closed with non-monetary relief              Yes                NaN
# 4  Closed with non-monetary relief              Yes                NaN
#
#    Complaint ID
# 0       8206605
# 1       8211390
# 2       8211362
# 3       8210433
# 4       8209430

# %%
df.isna().sum()
# Out:
# Date received                         0
# Product                               0
# Sub-product                      235292
# Issue                                 2
# Sub-issue                        734684
# Consumer complaint narrative    3329405
# Company public response         2677245
# Company                               0
# State                             45517
# ZIP code                          30225
# Tags                            4653480
# Consumer consent provided?      1024493
# Submitted via                         0
# Date sent to company                  0
# Company response to consumer         14
# Timely response?                      0
# Consumer disputed?              4366651
# Complaint ID                          0
# dtype: int64

# %%
# Replace null values in a categorical column with the mode
columns_to_fill = ['Sub-product', 'Issue', 'Sub-issue', 'Consumer complaint narrative','Company public response','State', 'ZIP code', 'ZIP code', 'Tags', 'Consumer consent provided?', 'Submitted via', 'Company response to consumer', 'Consumer disputed?']  # Specify columns to fill

for column in columns_to_fill:
    mode_value = df[column].mode()[0]  # Calculate mode value for the column
    df[column].fillna(mode_value, inplace=True)  # Fill missing values with mode value

# %%
df.isna().sum()
# Out:
# Date received                   0
# Product                         0
# Sub-product                     0
# Issue                           0
# Sub-issue                       0
# Consumer complaint narrative    0
# Company public response         0
# Company                         0
# State                           0
# ZIP code                        0
# Tags                            0
# Consumer consent provided?      0
# Submitted via                   0
# Date sent to company            0
# Company response to consumer    0
# Timely response?                0
# Consumer disputed?              0
# Complaint ID                    0
# Sub_product                     0
# dtype: int64

# %%
df.describe()
# Out:
#        Complaint ID   Sub_product
# count  5.134967e+06  5.134967e+06
# mean   5.128901e+06  2.439690e+01
# std    2.399565e+06  2.031648e+01
# min    1.000000e+00  0.000000e+00
# 25%    3.232238e+06  1.500000e+01
# 50%    5.364003e+06  1.500000e+01
# 75%    7.242070e+06  2.600000e+01
# max    8.898710e+06  8.600000e+01

# %%
# Analyze the frequency of complaints over time
df['Date received'] = pd.to_datetime(df['Date received'])
df['Year'] = df['Date received'].dt.year
complaints_by_year = df['Year'].value_counts().sort_index()
plt.figure(figsize=(10, 6))
sns.lineplot(x=complaints_by_year.index, y=complaints_by_year.values)
plt.title('Number of Complaints Over Time')
plt.xlabel('Year')
plt.ylabel('Number of Complaints')
plt.show()

# %%
# Most common products and sub-products associated with complaints
product_counts = df['Product'].value_counts()
subproduct_counts = df['Sub-product'].value_counts()

# %%
product_counts
